# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
mydata=pd.read_csv("CardioGoodFitness-1.csv")

# %%
##top 5 rows
mydata.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 142   TM798   22    Male         18        Single      4        5   48556
# 68    TM195   38    Male         16     Partnered      3        3   46617
# 145   TM798   23    Male         16        Single      4        5   48556
# 93    TM498   23    Male         16     Partnered      3        3   45480
# 118   TM498   32    Male         16        Single      4        3   60261
# 12    TM195   22  Female         16        Single      4        3   36384
# 85    TM498   21    Male         16     Partnered      2        2   34110
# 20    TM195   23    Male         14        Single      4        3   38658
# 75    TM195   43    Male         16     Partnered      3        3   53439
# 60    TM195   33  Female         16     Partnered      3        3   46617
#
#      Miles
# 142    200
# 68      75
# 145    100
# 93      64
# 118    127
# 12      75
# 85      42
# 20     113
# 75      66
# 60      85

# %%
mydata.shape
# Out:
# (180, 9)

# %%
mydata.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
mydata.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
### There are 180 non-null observations in all the attributes which indicates that there are no missing value

# %%
mydata.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
mydata.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
sns.boxplot(x="Age",data=mydata)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x="Education",data=mydata)
# Out:
# <Axes: xlabel='Education'>

# %%
sns.boxplot(x="Usage",data=mydata)
# Out:
# <Axes: xlabel='Usage'>

# %%
sns.boxplot(x="Fitness",data=mydata)
# Out:
# <Axes: xlabel='Fitness'>

# %%
sns.boxplot(x="Income",data=mydata)
# Out:
# <Axes: xlabel='Income'>

# %%
###Observe only number thing is used in sns.boxplot(x="_",data=mydata)
sns.boxplot(x="Miles",data=mydata)
# Out:
# <Axes: xlabel='Miles'>

# %%
### to ignore warning
import warnings
warnings.filterwarnings("ignore")

# %%
sns.distplot(mydata["Age"])
plt.show()

# %%
sns.distplot(mydata["Education"])
plt.show()

# %%
sns.distplot(mydata["Usage"])
plt.show()

# %%
sns.distplot(mydata["F"])
plt.show()

# %%
mydata.hist(figsize=(10,20))
plt.show()

# %%
mydata.describe(include="all").T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      TM195   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %%
sns.countplot(x="MaritalStatus",data=mydata)
### to plot the count of all categories
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
sns.countplot(x="Product",data=mydata)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="Gender",data=mydata)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x="Product",hue="Gender",data=mydata)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="Product",hue="MaritalStatus",data=mydata)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.countplot(x="MaritalStatus",hue="Gender",data=mydata)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
sns.boxplot(x="Product",y="Age",data=mydata) ###Boxplot-One should be numerical
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %%
sns.boxplot(x="Age",y="Product",data=mydata)
# Out:
# <Axes: xlabel='Age', ylabel='Product'>

# %%
sns.boxplot(x="MaritalStatus",y="Age",data=mydata)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Age'>

# %%
sns.boxplot(x="MaritalStatus",y="Education",data=mydata)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Education'>

# %%
sns.boxplot(x="MaritalStatus",y="Income",data=mydata)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Income'>

# %%
sns.boxplot(x="Fitness",y="MaritalStatus",data=mydata)
# Out:
# <Axes: xlabel='Fitness', ylabel='MaritalStatus'>

# %%
sns.boxplot(x="MaritalStatus",y="Miles",data=mydata)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='Miles'>

# %%
sns.boxplot(x="Fitness",y="Gender",data=mydata)
# Out:
# <Axes: xlabel='Fitness', ylabel='Gender'>

# %%
sns.boxplot(x="Education",y="Income",data=mydata)
# Out:
# <Axes: xlabel='Education', ylabel='Income'>

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.sample()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 168   TM798   30   Male         18     Partnered      5        4  103336
#
#      Miles
# 168    160

# %%
df.sample()
# Out:
#    Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 50   TM195   29   Male         18     Partnered      3        3   68220     85

# %%
df.sample(5
         )
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 167   TM798   30  Female         16     Partnered      6        5   90886
# 32    TM195   25  Female         16     Partnered      2        2   40932
# 88    TM498   23    Male         14     Partnered      3        3   38658
# 93    TM498   23    Male         16     Partnered      3        3   45480
# 58    TM195   32    Male         14     Partnered      4        3   52302
#
#      Miles
# 167    280
# 32      47
# 88      85
# 93      64
# 58      85

# %%
df.sample(5)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 132   TM498   37  Female         16     Partnered      2        3   48891
# 112   TM498   29  Female         14     Partnered      3        3   51165
# 13    TM195   22  Female         14        Single      3        3   35247
# 68    TM195   38    Male         16     Partnered      3        3   46617
# 1     TM195   19    Male         15        Single      2        3   31836
#
#      Miles
# 132     85
# 112     95
# 13      75
# 68      75
# 1       75

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# above done to show total data available

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# above done to show if any missing values
